# %%
#started the escercise aroun 4:30
from sklearn.datasets import make_blobs
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = make_blobs(n_samples=100, n_features=2, centers=5,random_state=101)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1])

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-4.05050671,  7.90104677],
#        [-9.56458048, -6.09665251],
#        [ 4.58002297, -6.28061932],
#        [ 3.62186823,  6.59111541],
#        [ 0.23713963,  1.85541645]])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(12,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
kmeans.labels_
# Out:
# array([0, 1, 2, 0, 4, 4, 3, 2, 1, 1, 4, 1, 1, 4, 4, 4, 3, 4, 2, 4, 2, 0,
#        2, 4, 4, 0, 1, 0, 2, 4, 1, 3, 2, 1, 1, 2, 0, 0, 1, 4, 3, 2, 4, 4,
#        3, 2, 0, 1, 1, 1, 0, 0, 3, 2, 1, 0, 4, 3, 2, 2, 1, 0, 3, 3, 2, 4,
#        0, 2, 1, 0, 2, 0, 3, 0, 3, 4, 3, 0, 1, 3, 1, 2, 3, 2, 0, 3, 3, 4,
#        1, 3, 2, 4, 0, 3, 1, 2, 0, 3, 3, 4], dtype=int32)

# %%
# finished excercise around 4:50
# estimated time was around 20 min
